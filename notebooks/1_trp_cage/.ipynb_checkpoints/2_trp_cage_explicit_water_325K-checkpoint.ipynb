# %% [markdown]
# In this simulation we start with a linear version of the 20 AA long Trp Cage sequence. The starting configuration was generated by hand using pymol to add the AA residues one by one which resulted in a linear combination.
#
# The simulation will proceed by solvating the molecule and adding counter ions to neutralise the solution, then performing an relaxation step to remove any strain in the protein. The temperature and pressure will then be equilibrated with the protein fixed, before starting the MD run to see if the protein will fold.
#
# In this simulation, the number of water molecules added is fixed at 2678 and the temperature held at 325K to make the potential energy comparable with the MD simulation of the NMR folded structure. The expected potential energy of the system when correctly folded is approx -125,000 kcal/mol.

# %%
# Preabmle to import our helper scripts and set up environment for a Gromacs simulation

import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from helpers.GromacsHelpers import *
# %matplotlib inline

# %%
# !mkdir -p zzz_scratch_2

# %%
cd zzz_scratch_2
# Out:
# /home/ubuntu/honours/notebooks/1 - Trp Cage/zzz_scratch_2

# %%
pymolPlotStructure("../trp_cage_linear.pdb")

# %%
gmx("pdb2gmx -f ../trp_cage_linear.pdb -o trp_cage_processed.gro -ignh -water spce", "15\n", verbose=False)
# Out:
# Select the Force Field:
# From '/home/ubuntu/gromacs-2016.2/share/gromacs/top':
#  1: AMBER03 protein, nucleic AMBER94 (Duan et al., J. Comp. Chem. 24, 1999-2012, 2003)
#  2: AMBER94 force field (Cornell et al., JACS 117, 5179-5197, 1995)
#  3: AMBER96 protein, nucleic AMBER94 (Kollman et al., Acc. Chem. Res. 29, 461-469, 1996)
#  4: AMBER99 protein, nucleic AMBER94 (Wang et al., J. Comp. Chem. 21, 1049-1074, 2000)
#  5: AMBER99SB protein, nucleic AMBER94 (Hornak et al., Proteins 65, 712-725, 2006)
#  6: AMBER99SB-ILDN protein, nucleic AMBER94 (Lindorff-Larsen et al., Proteins 78, 1950-58, 2010)
#  7: AMBERGS force field (Garcia & Sanbonmatsu, PNAS 99, 2782-2787, 2002)
#  8: CHARMM27 all-atom force field (CHARM22 plus CMAP for proteins)
#  9: GROMOS96 43a1 force field
# 10: GROMOS96 43a2 force field (improved alkane dihedrals)
# 11: GROMOS96 45a3 force field (Schuler JCC 2001 22 1205)
# 12: GROMOS96 53a5 force field (JCC 2004 vol 25 pag 1656)
# ...

# %%
gmx("editconf -f trp_cage_processed.gro -o trp_cage_newbox.gro -c -d 1.0 -bt cubic")
# Out:
# Read 304 atoms
# Volume: 36.3039 nm^3, corresponds to roughly 16300 electrons
# No velocities found
#     system size :  4.702  3.644  2.119 (nm)
#     diameter    :  5.546               (nm)
#     center      :  2.329  1.321  0.388 (nm)
#     box vectors :  4.702  3.643  2.119 (nm)
#     box angles  :  90.00  90.00  90.00 (degrees)
#     box volume  :  36.30               (nm^3)
#     shift       :  1.444  2.452  3.385 (nm)
# new center      :  3.773  3.773  3.773 (nm)
# new box vectors :  7.546  7.546  7.546 (nm)
# new box angles  :  90.00  90.00  90.00 (degrees)
# new box volume  : 429.69               (nm^3)

# %%
gmx("solvate -cp trp_cage_newbox.gro -cs spc216.gro -o trp_cage_solv.gro -p topol.top -maxsol 2678")
# Out:
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary.
#
# NOTE: From version 5.0 gmx solvate uses the Van der Waals radii
# from the source below. This means the results may be different
# compared to previous GROMACS versions.
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# A. Bondi
# van der Waals Volumes and Radii
# J. Phys. Chem. 68 (1964) pp. 441-451
# -------- -------- --- Thank You --- -------- --------
#
# Adding line for 2678 solvent molecules to topology file (topol.top)

# %%
# %%file ions.mdp
# ; ions.mdp - used as input into grompp to generate ions.tpr
# ; Parameters describing what to do, when to stop and what to save
# integrator  = steep     ; Algorithm (steep = steepest descent minimization)
# emtol       = 1000.0    ; Stop minimization when the maximum force < 1000.0 kJ/mol/nm
# emstep      = 0.01      ; Energy step size
# nsteps      = 50000     ; Maximum number of (minimization) steps to perform
#
# ; Parameters describing how to find the neighbors of each atom and how to calculate the interactions
# nstlist         = 1         ; Frequency to update the neighbor list and long range forces
# cutoff-scheme   = Verlet
# ns_type         = grid      ; Method to determine neighbor list (simple, grid)
# coulombtype     = PME       ; Treatment of long range electrostatic interactions
# rcoulomb        = 1.0       ; Short-range electrostatic cut-off
# rvdw            = 1.0       ; Short-range Van der Waals cut-off
# pbc             = xyz       ; Periodic Boundary Conditions (yes/no)
# Out:
# Writing ions.mdp

# %%
gmx("grompp -f ions.mdp -c trp_cage_solv.gro -p topol.top -o ions.tpr")
gmx("genion -s ions.tpr -o trp_cage_solv_ions.gro -p topol.top -pname NA -nname CL -nn 1", "13\n")
# Out:
# Analysing residue names:
# There are:    20    Protein residues
# There are:  2678      Water residues
# Analysing Protein...
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 64x64x64, spacing 0.118 0.118 0.118
# This run will generate roughly 1 Mb of data
# Will try to add 0 NA ions and 1 CL ions.
# Select a continuous group of solvent molecules
# Selected 13: 'SOL'
#
# Processing topology
# Replacing 1 solute molecules in topology file (topol.top)  by 0 NA and 1 CL ions.

# %%
# %%file minim.mdp
# ; minim.mdp - used as input into grompp to generate em.tpr
# ; Parameters describing what to do, when to stop and what to save
# integrator  = steep     ; Algorithm (steep = steepest descent minimization)
# emtol       = 1000.0    ; Stop minimization when the maximum force < 1000.0 kJ/mol/nm
# emstep      = 0.01      ; Energy step size
# nsteps      = 50000     ; Maximum number of (minimization) steps to perform
#
# ; Parameters describing how to find the neighbors of each atom and how to calculate the interactions
# nstlist         = 1         ; Frequency to update the neighbor list and long range forces
# cutoff-scheme   = Verlet
# ns_type         = grid      ; Method to determine neighbor list (simple, grid)
# coulombtype     = PME       ; Treatment of long range electrostatic interactions
# rcoulomb        = 1.0       ; Short-range electrostatic cut-off
# rvdw            = 1.0       ; Short-range Van der Waals cut-off
# pbc             = xyz       ; Periodic Boundary Conditions (yes/no)
# Out:
# Writing minim.mdp

# %%
gmx("grompp -f minim.mdp -c trp_cage_solv_ions.gro -p topol.top -o em.tpr")
gmx("mdrun -v -deffnm em")
# Out:
# Analysing residue names:
# There are:    20    Protein residues
# There are:  2677      Water residues
# There are:     1        Ion residues
# Analysing Protein...
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 64x64x64, spacing 0.118 0.118 0.118
# This run will generate roughly 1 Mb of data

# %%
gmx("energy -f em.edr -o potential.xvg", "10\n")
plotFigure("potential.xvg")
# Out:
# Statistics over 317 steps [ 0.0000 through 316.0000 ps ], 1 data sets
# All statistics are over 251 points (frames)
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Potential                   -124303       2700     6552.7   -17827.7  (kJ/mol)

# %%
pymolPlotGro("em.gro")
# Out:
# Read 8336 atoms
# Volume: 429.687 nm^3, corresponds to roughly 193300 electrons
# No velocities found

# %%
# %%file nvt.mdp
# define      = -DPOSRES  ; position restrain the protein
# ; Run parameters
# integrator  = md        ; leap-frog integrator
# nsteps      = 50000     ; 2 * 50000 = 100 ps
# dt          = 0.002     ; 2 fs
#
# ; Output control
# nstxout     = 500       ; save coordinates every 1.0 ps
# nstvout     = 500       ; save velocities every 1.0 ps
# nstenergy   = 500       ; save energies every 1.0 ps
# nstlog      = 500       ; update log file every 1.0 ps
#
# ; Bond parameters
# continuation            = no        ; first dynamics run
# constraint_algorithm    = lincs     ; holonomic constraints
# constraints             = all-bonds ; all bonds (even heavy atom-H bonds) constrained
# lincs_iter              = 1         ; accuracy of LINCS
# lincs_order             = 4         ; also related to accuracy
#
# ; Neighborsearching
# cutoff-scheme   = Verlet
# ns_type         = grid      ; search neighboring grid cells
# nstlist         = 10        ; 20 fs, largely irrelevant with Verlet
# rcoulomb        = 1.0       ; short-range electrostatic cutoff (in nm)
# rvdw            = 1.0       ; short-range van der Waals cutoff (in nm)
#
# ; Electrostatics
# coulombtype     = PME   ; Particle Mesh Ewald for long-range electrostatics
# pme_order       = 4     ; cubic interpolation
# fourierspacing  = 0.16  ; grid spacing for FFT
#
# ; Temperature coupling is on
# tcoupl      = V-rescale             ; modified Berendsen thermostat
# tc-grps     = Protein Non-Protein   ; two coupling groups - more accurate
# tau_t       = 0.1  0.1              ; time constant, in ps
# ref_t       = 325  325              ; reference temperature, one for each group, in K
#
# ; Pressure coupling is off
# pcoupl      = no        ; no pressure coupling in NVT
#
# ; Periodic boundary conditions
# pbc         = xyz       ; 3-D PBC
#
# ; Dispersion correction
# DispCorr    = EnerPres  ; account for cut-off vdW scheme
#
# ; Velocity generation
# gen_vel     = yes       ; assign velocities from Maxwell distribution
# gen_temp    = 325       ; temperature for Maxwell distribution
# gen_seed    = -1        ; generate a random seed
# Out:
# Writing nvt.mdp

# %%
gmx("grompp -f nvt.mdp -c em.gro -p topol.top -o nvt.tpr")
gmx("mdrun -v -deffnm nvt", verbose=False)
# Out:
# turning all bonds into constraints...
# turning all bonds into constraints...
# turning all bonds into constraints...
# Analysing residue names:
# There are:    20    Protein residues
# There are:  2677      Water residues
# There are:     1        Ion residues
# Analysing Protein...
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 325 K
# Calculated rlist for 1x1 atom pair-list as 1.013 nm, buffer size 0.013 nm
# Set rlist, assuming 4x4 atom pair-list, to 1.000 nm, buffer size 0.000 nm
# Note that mdrun will redetermine rlist based on the actual pair-list setup
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 48x48x48, spacing 0.157 0.157 0.157
# This run will generate roughly 20 Mb of data
# :-) GROMACS - gmx mdrun, 2016.2 (-:
#
#                             GROMACS is written by:
# ...

# %%
gmx("energy -f nvt.edr -o temperature.xvg", "15\n")
plotFigure("temperature.xvg")
# Out:
# Statistics over 50001 steps [ 0.0000 through 100.0000 ps ], 1 data sets
# All statistics are over 501 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Temperature                 324.614       0.16    4.30299   0.661498  (K)

# %%
# %%file npt.mdp
# define      = -DPOSRES  ; position restrain the protein
# ; Run parameters
# integrator  = md        ; leap-frog integrator
# nsteps      = 50000     ; 2 * 50000 = 100 ps
# dt          = 0.002     ; 2 fs
#
# ; Output control
# nstxout     = 500       ; save coordinates every 1.0 ps
# nstvout     = 500       ; save velocities every 1.0 ps
# nstenergy   = 500       ; save energies every 1.0 ps
# nstlog      = 500       ; update log file every 1.0 ps
#
# ; Bond parameters
# continuation            = yes       ; restarting acter NVT
# constraint_algorithm    = lincs     ; holonomic constraints
# constraints             = all-bonds ; all bonds (even heavy atom-H bonds) constrained
# lincs_iter              = 1         ; accuracy of LINCS
# lincs_order             = 4         ; also related to accuracy
#
# ; Neighborsearching
# cutoff-scheme   = Verlet
# ns_type         = grid      ; search neighboring grid cells
# nstlist         = 10        ; 20 fs, largely irrelevant with Verlet
# rcoulomb        = 1.0       ; short-range electrostatic cutoff (in nm)
# rvdw            = 1.0       ; short-range van der Waals cutoff (in nm)
#
# ; Electrostatics
# coulombtype     = PME   ; Particle Mesh Ewald for long-range electrostatics
# pme_order       = 4     ; cubic interpolation
# fourierspacing  = 0.16  ; grid spacing for FFT
#
# ; Temperature coupling is on
# tcoupl      = V-rescale             ; modified Berendsen thermostat
# tc-grps     = Protein Non-Protein   ; two coupling groups - more accurate
# tau_t       = 0.1  0.1              ; time constant, in ps
# ref_t       = 325  325              ; reference temperature, one for each group, in K
#
# ; Pressure coupling is on
# pcoupl              = Parrinello-Rahman     ; Pressure coupling on in NPT
# pcoupltype          = isotropic             ; uniform scaling of box vectors
# tau_p               = 2.0                   ; time constant, in ps
# ref_p               = 1.0                   ; reference pressure, in bar
# compressibility     = 4.5e-5                ; isothermal compressibility of water, bar^-1
# refcoord_scaling    = com
#
# ; Periodic boundary conditions
# pbc         = xyz       ; 3-D PBC
#
# ; Dispersion correction
# DispCorr    = EnerPres  ; account for cut-off vdW scheme
#
# ; Velocity generation
# gen_vel     = no       ; Velocity generation is off
# Out:
# Writing npt.mdp

# %%
gmx("grompp -f npt.mdp -c nvt.gro -t nvt.cpt -p topol.top -o npt.tpr")
gmx("mdrun -v -deffnm npt")
# Out:
# turning all bonds into constraints...
# turning all bonds into constraints...
# turning all bonds into constraints...
# Analysing residue names:
# There are:    20    Protein residues
# There are:  2677      Water residues
# There are:     1        Ion residues
# Analysing Protein...
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 325 K
# Calculated rlist for 1x1 atom pair-list as 1.013 nm, buffer size 0.013 nm
# Set rlist, assuming 4x4 atom pair-list, to 1.000 nm, buffer size 0.000 nm
# Note that mdrun will redetermine rlist based on the actual pair-list setup
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 48x48x48, spacing 0.157 0.157 0.157
# This run will generate roughly 20 Mb of data

# %%
gmx("energy -f npt.edr -o pressure.xvg", "16\n")
plotFigure("pressure.xvg")
# Out:
# Statistics over 50001 steps [ 0.0000 through 100.0000 ps ], 1 data sets
# All statistics are over 501 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Pressure                    3.00217        5.1    282.356    12.1561  (bar)

# %%
gmx("energy -f npt.edr -o density.xvg", "22\n")
plotFigure("density.xvg")
# Out:
# Statistics over 50001 steps [ 0.0000 through 100.0000 ps ], 1 data sets
# All statistics are over 501 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Density                     840.439        140    283.889    739.068  (kg/m^3)

# %%
# %%file md.mdp
# ; Run parameters
# integrator  = md        ; leap-frog integrator
# nsteps      = 500000    ; 2 * 500000 = 1000 ps (1 ns)
# dt          = 0.002     ; 2 fs
#
# ; Output control
# nstxout     = 5000       ; save coordinates every 10.0 ps
# nstvout     = 5000       ; save velocities every 10.0 ps
# nstenergy   = 5000       ; save energies every 10.0 ps
# nstlog      = 5000       ; update log file every 10.0 ps
# nstxout-compressed  = 5000      ; save compressed coordinates every 10.0 ps
#                                 ; nstxout-compressed replaces nstxtcout
# compressed-x-grps   = System    ; replaces xtc-grps
#
# ; Bond parameters
# continuation            = yes       ; restarting acter NPT
# constraint_algorithm    = lincs     ; holonomic constraints
# constraints             = all-bonds ; all bonds (even heavy atom-H bonds) constrained
# lincs_iter              = 1         ; accuracy of LINCS
# lincs_order             = 4         ; also related to accuracy
#
# ; Neighborsearching
# cutoff-scheme   = Verlet
# ns_type         = grid      ; search neighboring grid cells
# nstlist         = 10        ; 20 fs, largely irrelevant with Verlet
# rcoulomb        = 1.0       ; short-range electrostatic cutoff (in nm)
# rvdw            = 1.0       ; short-range van der Waals cutoff (in nm)
#
# ; Electrostatics
# coulombtype     = PME   ; Particle Mesh Ewald for long-range electrostatics
# pme_order       = 4     ; cubic interpolation
# fourierspacing  = 0.16  ; grid spacing for FFT
#
# ; Temperature coupling is on
# tcoupl      = V-rescale             ; modified Berendsen thermostat
# tc-grps     = Protein Non-Protein   ; two coupling groups - more accurate
# tau_t       = 0.1  0.1              ; time constant, in ps
# ref_t       = 325  325              ; reference temperature, one for each group, in K
#
# ; Pressure coupling is on
# pcoupl              = Parrinello-Rahman     ; Pressure coupling on in NPT
# pcoupltype          = isotropic             ; uniform scaling of box vectors
# tau_p               = 2.0                   ; time constant, in ps
# ref_p               = 1.0                   ; reference pressure, in bar
# compressibility     = 4.5e-5                ; isothermal compressibility of water, bar^-1
# refcoord_scaling    = com
#
# ; Periodic boundary conditions
# pbc         = xyz       ; 3-D PBC
#
# ; Dispersion correction
# DispCorr    = EnerPres  ; account for cut-off vdW scheme
#
# ; Velocity generation
# gen_vel     = no       ; Velocity generation is off
# Out:
# Writing md.mdp

# %%
gmx("grompp -f md.mdp -c npt.gro -t npt.cpt -p topol.top -o md_0_1.tpr")
gmx("mdrun -v -deffnm md_0_1")
# Out:
# turning all bonds into constraints...
# turning all bonds into constraints...
# turning all bonds into constraints...
# Analysing residue names:
# There are:    20    Protein residues
# There are:  2677      Water residues
# There are:     1        Ion residues
# Analysing Protein...
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 325 K
# Calculated rlist for 1x1 atom pair-list as 1.038 nm, buffer size 0.038 nm
# Set rlist, assuming 4x4 atom pair-list, to 1.000 nm, buffer size 0.000 nm
# Note that mdrun will redetermine rlist based on the actual pair-list setup
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 28x28x28, spacing 0.157 0.157 0.157
# This run will generate roughly 24 Mb of data

# %%
gmx("trjconv -s md_0_1.tpr -f md_0_1.xtc -o md_0_1_noPBC.xtc -pbc mol -ur compact", "0\n")
gmx("rms -s md_0_1.tpr -f md_0_1_noPBC.xtc -o rmsd.xvg -tu ns", "4\n4\n")
plotFigure("rmsd.xvg")
# Out:
# Select group for output
# Selected 0: 'System'
# Selected 4: 'Backbone'
# Selected 4: 'Backbone'

# %%
gmx("energy -f md_0_1.edr -o pe.xvg", "10\n")
plotFigure("pe.xvg")
# Out:
# Statistics over 500001 steps [ 0.0000 through 1000.0000 ps ], 1 data sets
# All statistics are over 5001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Potential                   -124935         10    395.796    -66.577  (kJ/mol)

# %%
gmx("trjconv -s md_0_1.tpr -f md_0_1_noPBC.xtc -o md_0_1.pdb -pbc nojump -dt 10", "1\n")
# Out:
# Select group for output
# Selected 1: 'Protein'

# %%
pymolPlotGro("md_0_1.gro")
# Out:
# Read 8336 atoms
# Volume: 84.53 nm^3, corresponds to roughly 38000 electrons
# Velocities found

# %%
# %%file md2.mdp
# ; Run parameters
# integrator  = md        ; leap-frog integrator
# nsteps      = 25000000   ; 2 * 25000000 = 5000 ps (50 ns)
# dt          = 0.002     ; 2 fs
#
# ; Output control
# nstxout     = 5000       ; save coordinates every 10.0 ps
# nstvout     = 5000       ; save velocities every 10.0 ps
# nstenergy   = 5000       ; save energies every 10.0 ps
# nstlog      = 5000       ; update log file every 10.0 ps
# nstxout-compressed  = 5000      ; save compressed coordinates every 10.0 ps
#                                 ; nstxout-compressed replaces nstxtcout
# compressed-x-grps   = System    ; replaces xtc-grps
#
# ; Bond parameters
# continuation            = yes       ; restarting acter NPT
# constraint_algorithm    = lincs     ; holonomic constraints
# constraints             = all-bonds ; all bonds (even heavy atom-H bonds) constrained
# lincs_iter              = 1         ; accuracy of LINCS
# lincs_order             = 4         ; also related to accuracy
#
# ; Neighborsearching
# cutoff-scheme   = Verlet
# ns_type         = grid      ; search neighboring grid cells
# nstlist         = 10        ; 20 fs, largely irrelevant with Verlet
# rcoulomb        = 1.0       ; short-range electrostatic cutoff (in nm)
# rvdw            = 1.0       ; short-range van der Waals cutoff (in nm)
#
# ; Electrostatics
# coulombtype     = PME   ; Particle Mesh Ewald for long-range electrostatics
# pme_order       = 4     ; cubic interpolation
# fourierspacing  = 0.16  ; grid spacing for FFT
#
# ; Temperature coupling is on
# tcoupl      = V-rescale             ; modified Berendsen thermostat
# tc-grps     = Protein Non-Protein   ; two coupling groups - more accurate
# tau_t       = 0.1  0.1              ; time constant, in ps
# ref_t       = 325  325              ; reference temperature, one for each group, in K
#
# ; Pressure coupling is on
# pcoupl              = Parrinello-Rahman     ; Pressure coupling on in NPT
# pcoupltype          = isotropic             ; uniform scaling of box vectors
# tau_p               = 2.0                   ; time constant, in ps
# ref_p               = 1.0                   ; reference pressure, in bar
# compressibility     = 4.5e-5                ; isothermal compressibility of water, bar^-1
# refcoord_scaling    = com
#
# ; Periodic boundary conditions
# pbc         = xyz       ; 3-D PBC
#
# ; Dispersion correction
# DispCorr    = EnerPres  ; account for cut-off vdW scheme
#
# ; Velocity generation
# gen_vel     = no       ; Velocity generation is off
# Out:
# Overwriting md2.mdp

# %% [markdown]
# Lets run it for a longer run of 50 nS now to see if it will fold... (note this is a 7 hour job on an AWS-EC2-P2.xlarge)

# %%
gmx("grompp -f md2.mdp -c md_0_1.gro -t md_0_1.cpt -p topol.top -o md_0_2.tpr")
gmx("mdrun -v -deffnm md_0_2")
# Out:
# turning all bonds into constraints...
# turning all bonds into constraints...
# turning all bonds into constraints...
# Analysing residue names:
# There are:    20    Protein residues
# There are:  2677      Water residues
# There are:     1        Ion residues
# Analysing Protein...
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 325 K
# Calculated rlist for 1x1 atom pair-list as 1.038 nm, buffer size 0.038 nm
# Set rlist, assuming 4x4 atom pair-list, to 1.000 nm, buffer size 0.000 nm
# Note that mdrun will redetermine rlist based on the actual pair-list setup
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 28x28x28, spacing 0.157 0.157 0.157
# This run will generate roughly 1173 Mb of data

# %%
gmx("energy -f md_0_2.edr -o pe2.xvg", "10\n")
plotFigure("pe2.xvg")
